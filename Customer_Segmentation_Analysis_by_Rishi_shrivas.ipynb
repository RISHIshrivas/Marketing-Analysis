# %% [markdown]
# ## PROJECT ASSIGNMENT-2
# #Customer Segmentation Analysis
# by Rishi Shrivas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")
import seaborn as sns
from scipy.stats import pointbiserialr

# %%
csa = pd.read_csv("marketing analytics.csv")

# %%
csa
# Out:
#                  Feature                                        Description  \
# 0           AcceptedCmp1  1 if customer accepted the offer in the 1st ca...
# 1           AcceptedCmp2  1 if customer accepted the offer in the 2nd ca...
# 2           AcceptedCmp3  1 if customer accepted the offer in the 3rd ca...
# 3           AcceptedCmp4  1 if customer accepted the offer in the 4th ca...
# 4           AcceptedCmp5  1 if customer accepted the offer in the 5th ca...
# 5     AcceptedCmpOverall               overall number of accepted campaigns
# 6               Response  1 if customer accepted the offer in the last c...
# 7               Complain       1 if customer complained in the last 2 years
# 8             DtCustomer      date of customer’s enrolment with the company
# 9          Customer_Days    number of days since registration as a customer
# 10             Education                      customer’s level of education
# 11    education_2n Cycle                   customer has secondary education
# 12       education_Basic                       customer has basic education
# 13  education_Graduation                     Customer has a bachelor degree
# 14      education_Master                      Customer has a masters degree
# 15         education_PhD                                 Customer has a PhD
# 16               Marital                         customer’s marital status.
# 17      marital_Divorced            1 if customer is divorced, 0 otherwise.
# 18       marital_Married             1 if customer is married, 0 otherwise.
# 19        marital_Single              1 if customer is single, 0 otherwise.
# 20      marital_Together     1 if customer is in relationship, 0 otherwise.
# 21         marital_Widow    1 if customer is a widow / widower, 0 otherwise
# 22               Kidhome   number of small children in customer’s household
# 23              Teenhome        number of teenagers in customer’s household
# 24                Income                 customer’s yearly household income
# 25       MntFishProducts  amount spent on fish products in the last 2 years
# 26       MntMeatProducts  amount spent on meat products in the last 2 years
# 27             MntFruits  amount spent on fruits products in the last 2 ...
# 28      MntSweetProducts  amount spent on sweet products in the last 2 y...
# 29              MntWines  amount spent on wine products in the last 2 years
# 30          MntGoldProds  amount spent on gold products in the last 2 years
# 31     NumDealsPurchases             number of purchases made with discount
# 32   NumCatalogPurchases           number of purchases made using catalogue
# 33     NumStorePurchases        number of purchases made directly in stores
# 34       NumWebPurchases  number of purchases made through company’s web...
# 35     NumWebVisitsMonth  number of visits to company’s web site in the ...
# 36               Recency             number of days since the last purchase
# 37         Z_CostContact                                                NaN
# 38             Z_Revenue                                                NaN
# 39                   Age                                    Age of customer
# 40              MntTotal             Total amount spent on all the products
# 41       MntRegularProds                                                NaN
#
#                                               Comment
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   This column was added from the list of actual ...
# 6                                                 NaN
# 7                                                 NaN
# 8              There is no such column in the dataset
# 9                                                 NaN
# 10      There is no such column in the actual dataset
# 11  This column was added from the list of actual ...
# 12  This column was added from the list of actual ...
# 13  This column was added from the list of actual ...
# 14  This column was added from the list of actual ...
# 15  This column was added from the list of actual ...
# 16      There is no such column in the actual dataset
# 17  This column was added from the list of actual ...
# 18  This column was added from the list of actual ...
# 19  This column was added from the list of actual ...
# 20  This column was added from the list of actual ...
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  This column was added from the list of actual ...
# 38  This column was added from the list of actual ...
# 39  This column was added from the list of actual ...
# 40  This column was added from the list of actual ...
# 41  This column was added from the list of actual ...

# %%
csa.head()
# Out:
#         Feature                                        Description Comment
# 0  AcceptedCmp1  1 if customer accepted the offer in the 1st ca...     NaN
# 1  AcceptedCmp2  1 if customer accepted the offer in the 2nd ca...     NaN
# 2  AcceptedCmp3  1 if customer accepted the offer in the 3rd ca...     NaN
# 3  AcceptedCmp4  1 if customer accepted the offer in the 4th ca...     NaN
# 4  AcceptedCmp5  1 if customer accepted the offer in the 5th ca...     NaN

# %%
csa.columns
# Out:
# Index(['Feature', 'Description', 'Comment'], dtype='object')

# %%
csa.isna().sum()
# Out:
# Feature         0
# Description     3
# Comment        24
# dtype: int64

# %%
csa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Feature      42 non-null     object
#  1   Description  39 non-null     object
#  2   Comment      18 non-null     object
# dtypes: object(3)
# memory usage: 1.1+ KB

# %%
csa.nunique()
# Out:
# Feature        42
# Description    39
# Comment         3
# dtype: int64

# %%
plt.figure(figsize=(15, 10))
sns.boxplot(data=csa, palette='rainbow')
plt.title("Box Plot of Customer Segmentation Analysis Data", fontsize=16)
plt.xlabel("Variables", fontsize=16)
plt.ylabel("Values", fontsize=16)
plt.show()
